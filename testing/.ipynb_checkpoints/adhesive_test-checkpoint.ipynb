# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from ase.io import read, write, Trajectory
from glob import glob
from mace.calculators import MACECalculator
import sys
from matplotlib.ticker import MultipleLocator
from matplotlib.lines import Line2D
from pathlib import Path
from ase.build.surface import mx2
from ase.optimize import BFGS
from ase.constraints import FixedLine

model_path = "/home/theory/phrrpq/Research_Data/quaternary_test/bilayer_models/MoWSSe_bi_radius_8_reduced_all_1_swa_800_run-123_swa.model"
calc=MACECalculator(model_paths=model_path, device="cuda", default_dtype="float64")

# --- Energy Computation Helper ---
def compute_adhesive_energy(atoms, tmdc1, tmdc2, use_mace=False):
    
    if use_mace:
        atoms.calc = calc
    energy = atoms.get_potential_energy()
    area = atoms.get_volume() / atoms.cell[2][2]
    adhesive_energy = 100 * (energy - mono_es[tmdc1] - mono_es[tmdc2]) / area
    return adhesive_energy

def passlog():
    pass

# --- Monolayer Energies ---
mono_es = {
    'MoS2': read('primitive/prim_MoS2.pwo').get_potential_energy(),
    'MoSe2': read('primitive/prim_MoSe2.pwo').get_potential_energy(),
    'WS2': read('primitive/prim_WS2.pwo').get_potential_energy(),
    'WSe2': read('primitive/prim_WSe2.pwo').get_potential_energy()
}

# --- Constants ---
LW = 0.3
MARKERSIZE = 3
FONT_SIZE = 7
plt.rcParams['font.size'] = FONT_SIZE

def plot_energy_curves(ax, ds, tmdc1, tmdc2, stacking, stacknames,foldername, path_fmt, skip_first=False):
    
    legend_elements = []
    for k in range(6):
        dft_energies = np.zeros(len(ds))
        mace_energies = np.zeros(len(ds))

        for l, d in enumerate(ds):
            filename = Path(path_fmt.format(foldername=foldername,
                                            tmdc1=tmdc1, tmdc2=tmdc2,
                                            stacking=stacking, idx=k+1,
                                            d=d))
        
            if not filename.exists():
                continue
            if filename.name == 'WSe2_WSe2_P1_d5.500.pwo':
                continue
                
            atoms = read(filename)
            dft_energies[l] = compute_adhesive_energy(atoms, tmdc1, tmdc2, use_mace=False)
            mace_energies[l] = compute_adhesive_energy(atoms, tmdc1, tmdc2, use_mace=True)

        if skip_first and tmdc1 == 'WSe2' and tmdc2 == 'WSe2' and stacking == 'P' and k == 0:
            x_vals, dft_y, mace_y = ds[1:], dft_energies[1:], mace_energies[1:]
        else:
            x_vals, dft_y, mace_y = ds, dft_energies, mace_energies

        solid = ax.plot(x_vals, dft_y, marker='o', markersize=MARKERSIZE-2, lw=LW)
        ax.plot(x_vals, mace_y, marker='x', linestyle='--',
                color=solid[0].get_color(), markerfacecolor='none',
                markersize=MARKERSIZE-1, lw=LW)
        label = stacknames[k + 1]
        legend_elements.append(Line2D([0], [0], color=solid[0].get_color(), label=label, lw=0.5))
        
    ax.set_ylim(-4.5, 3)
    ax.xaxis.set_minor_locator(MultipleLocator(0.1))
    ax.xaxis.set_major_locator(MultipleLocator(0.5))
    ax.yaxis.set_minor_locator(MultipleLocator(0.1))
    ax.yaxis.set_major_locator(MultipleLocator(1))

    ax.text(0.98, 0.98, rf"{stacking}-{tmdc1[:-1]}$_2$/{tmdc2[:-1]}$_2$", transform=ax.transAxes,
    fontsize=FONT_SIZE + 4, ha='right', va='top')


    legend_loc = 'lower left' if 'Se' in tmdc1 else 'lower right'
    ax.legend(handles=legend_elements, fontsize=FONT_SIZE - 2.25, frameon=False, loc=legend_loc)

def add_fixed_line_constraints(atoms):
    from ase.constraints import FixedLine
    constraints = [FixedLine(i, direction=[0, 0, 1]) for i in range(len(atoms))]
    atoms.set_constraint(constraints)    

def relax_structure(atoms, calculator, fmax=0.001):
    atoms.calc = calculator
    dyn = BFGS(atoms)
    dyn.log = passlog
    dyn.run(fmax=fmax)

bilayers = [('MoS2','MoS2'),('WS2','WS2'),('MoS2','WS2'),
            ('MoSe2','MoSe2'),('WSe2','WSe2'),('MoSe2','WSe2')]


def get_stacking_minima(tmdc1, tmdc2, stacking, offsets, stack_labels, initial_d, foldername, tag='', test=False):
    
    for k, offset in enumerate(offsets):
        idx = k if stacking == 'P' else k + len(offsets)
        suffix = f"test{k+1}" if test else f"{k+1}"
        filename = f"{foldername}/{tmdc1}_{tmdc2}_{stacking}{suffix}_d{initial_d:.3f}.pwo"
        
        bilayer = read(filename)
        dft_es[idx]  = compute_adhesive_energy(bilayer, tmdc1, tmdc2)
        dft_ds[idx] = np.abs(bilayer[0].z-bilayer[3].z)
        
        add_fixed_line_constraints(bilayer)
        relax_structure(bilayer, calc)
        ml_es[idx] = compute_adhesive_energy(bilayer, tmdc1, tmdc2, calc)
        ml_ds[idx] = np.abs(bilayer[0].z-bilayer[3].z)
        print(f'{stack_labels[k+1]}    DFT_d:{dft_ds[idx]:.3f} ML_d:{ml_ds[idx]:.3f} '
              f'DFT_energy:{dft_es[idx]:.3f} ML_energy:{ml_es[idx]:.3f}')
# Out:
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %% [markdown]
# # Plotting DFT vs MLIP adhesive energy densities as a function of interlayer d for different stackings included in training dataset

# %%
ds = np.linspace(5.5, 8, 11)
P_stacks = {1:"XX'", 2:"2", 3:"3R(MX')", 4:"4", 5:"3R(XM')", 6:"6"}
AP_stacks = {1:"XX'", 2:"2", 3:"2H", 4:"4", 5:"MM'", 6:"6"}
stacknames_list = [P_stacks, AP_stacks]

fig, axs = plt.subplots(6, 2, figsize=(6.5, 15))
foldername = 'aligned_train/'
for i, (tmdc1, tmdc2) in enumerate(bilayers):
    for j, stacking in enumerate(['P', 'AP']):
        stack_dict = stacknames_list[j]
        ax = axs[i][j]
        path_fmt = '{foldername}/{tmdc1}_{tmdc2}_{stacking}{idx}_d{d:0.3f}.pwo'
        plot_energy_curves(ax, ds, tmdc1, tmdc2, stacking, stack_dict, foldername, path_fmt, skip_first=True)

        if i != len(bilayers) - 1:
            ax.tick_params(labelbottom=False)
        if j != 0:
            ax.tick_params(labelleft=False)

plt.subplots_adjust(wspace=0.05, hspace=0.1)
fig.text(0.5, 0.1, r'interlayer distance, d (Å)', ha='center', fontsize=FONT_SIZE + 2)
fig.text(0.05, 0.5, 'adhesive energy density, W (eV/nm$^{2}$)', va='center', rotation='vertical', fontsize=FONT_SIZE + 2.5)

plt.savefig('energy_vs_d_dft_mace_train', facecolor='white', transparent=False, dpi=300,
            bbox_inches='tight', pad_inches=0.02)
plt.show()

# %% [markdown]
# # Plotting DFT vs MLIP adhesive energy densities as a function of interlayer d for random stackings created for testing

# %%
# --- System Setup ---
ds = np.linspace(5.5,8,11)+0.15
nstacks = 6
P_stacks = {1:"T1",2:"T2",3:"T3",4:"T4",5:"T5",6:"T6"}
AP_stacks = P_stacks
stacknames_list = [P_stacks, AP_stacks]

# --- Plotting ---
fig, axs = plt.subplots(6, 2, figsize=(6.5, 15))
foldername = 'aligned_test'
for i, (tmdc1, tmdc2) in enumerate(bilayers):
    for j, stacking in enumerate(['P', 'AP']):
        stack_dict = stacknames_list[j]
        ax = axs[i][j]
        path_fmt = '{foldername}/{tmdc1}_{tmdc2}_{stacking}test{idx}_d{d:0.3f}.pwo'
        plot_energy_curves(ax, ds, tmdc1, tmdc2, stacking, stack_dict,
                           foldername, path_fmt, skip_first=False)

        if i != len(bilayers) - 1:
            ax.tick_params(labelbottom=False)
        if j != 0:
            ax.tick_params(labelleft=False)

# --- Labels and Export ---
plt.subplots_adjust(wspace=0.05, hspace=0.1)
fig.text(0.5, 0.1, r'interlayer distance, d (Å)', ha='center', fontsize=FONT_SIZE + 2)
fig.text(0.05, 0.5, 'adhesive energy density, W (eV/nm$^{2}$)', va='center', rotation='vertical', fontsize=FONT_SIZE + 2.5)

plt.savefig('energy_vs_d_dft_mace_test', facecolor='white', transparent=False, dpi=300,
            bbox_inches='tight', pad_inches=0.02)
plt.show()

# %% [markdown]
# # Get minima for stackings in both train and test

# %%
P_offsets = np.array([[0,0],[0,1/(2*np.sqrt(3))],
            [0,-1/np.sqrt(3)],[0,1*np.sqrt(3)/2],
            [0,1/np.sqrt(3)],[-1/3,1/np.sqrt(3)]])

AP_offsets = np.array([[0,0],[0,-1/(2*np.sqrt(3))],
            [0,-1/np.sqrt(3)],[0,1/(2*np.sqrt(3))],
            [0,1/np.sqrt(3)],[-1/3,0]])

P_stacks = {1:"XX'",2:"2",3:"3R(MX')",4:"4",5:"3R(XM')",6:"f(d)"}
AP_stacks = {1:"XX'",2:"2",3:"2H",4:"4",5:"MM'",6:"f(d)"}

initial_d = 6.5
foldername = 'espresso_relax_train/'
for tmdc1, tmdc2 in bilayers:
    print(f"--- {tmdc1}/{tmdc2} ---")
    
    dft_ds, dft_es, ml_ds, ml_es = np.zeros(12), np.zeros(12), np.zeros(12), np.zeros(12)
    for j, stacking in enumerate(['P', 'AP']):
        print(f'Starting calculations for {stacking}-{tmdc1}/{tmdc2}')
        offsets = P_offsets if stacking == 'P' else AP_offsets
        stacks = P_stacks if stacking == 'P' else AP_stacks

        get_stacking_minima(tmdc1, tmdc2, stacking, offsets, stacks, initial_d, foldername)

    mae_es = np.mean(np.abs(dft_es - ml_es))
    mae_ds = np.mean(np.abs(dft_ds - ml_ds))
    print(f'{tmdc1}/{tmdc2} MAE_es: {mae_es:.3f} MAE_ds: {mae_ds:.3f}\n')
# Out:
# --- MoS2/MoS2 ---
# Starting calculations for P-MoS2/MoS2
# XX'    DFT_d:6.808 ML_d:6.807 DFT_energy:-1.854 ML_energy:-1.812
# 2    DFT_d:6.500 ML_d:6.571 DFT_energy:-2.101 ML_energy:-2.016
# 3R(MX')    DFT_d:6.237 ML_d:6.173 DFT_energy:-2.568 ML_energy:-2.492
# 4    DFT_d:6.378 ML_d:6.285 DFT_energy:-2.414 ML_energy:-2.309
# 3R(XM')    DFT_d:6.238 ML_d:6.173 DFT_energy:-2.568 ML_energy:-2.492
# f(d)    DFT_d:6.501 ML_d:6.500 DFT_energy:-2.197 ML_energy:-2.087
# Starting calculations for AP-MoS2/MoS2
# XX'    DFT_d:6.782 ML_d:6.782 DFT_energy:-1.888 ML_energy:-1.820
# 2    DFT_d:6.500 ML_d:6.575 DFT_energy:-2.132 ML_energy:-2.036
# 2H    DFT_d:6.251 ML_d:6.189 DFT_energy:-2.572 ML_energy:-2.517
# 4    DFT_d:6.500 ML_d:6.555 DFT_energy:-2.095 ML_energy:-1.999
# MM'    DFT_d:6.499 ML_d:6.195 DFT_energy:-2.375 ML_energy:-2.401
# f(d)    DFT_d:6.501 ML_d:6.490 DFT_energy:-2.195 ML_energy:-2.087
# MoS2/MoS2 MAE_es: 0.079 MAE_ds: 0.067
#
# --- WS2/WS2 ---
# Starting calculations for P-WS2/WS2
# XX'    DFT_d:6.822 ML_d:6.836 DFT_energy:-1.877 ML_energy:-1.825
# 2    DFT_d:6.500 ML_d:6.606 DFT_energy:-2.107 ML_energy:-2.022
# 3R(MX')    DFT_d:6.277 ML_d:6.223 DFT_energy:-2.563 ML_energy:-2.464
# 4    DFT_d:6.499 ML_d:6.331 DFT_energy:-2.395 ML_energy:-2.296
# 3R(XM')    DFT_d:6.279 ML_d:6.223 DFT_energy:-2.564 ML_energy:-2.464
# f(d)    DFT_d:6.500 ML_d:6.530 DFT_energy:-2.205 ML_energy:-2.089
# Starting calculations for AP-WS2/WS2
# XX'    DFT_d:6.805 ML_d:6.817 DFT_energy:-1.911 ML_energy:-1.828
# 2    DFT_d:6.500 ML_d:6.610 DFT_energy:-2.138 ML_energy:-2.042
# 2H    DFT_d:6.290 ML_d:6.235 DFT_energy:-2.586 ML_energy:-2.494
# 4    DFT_d:6.500 ML_d:6.589 DFT_energy:-2.098 ML_energy:-2.004
# MM'    DFT_d:6.499 ML_d:6.257 DFT_energy:-2.386 ML_energy:-2.367
# f(d)    DFT_d:6.500 ML_d:6.529 DFT_energy:-2.203 ML_energy:-2.090
# WS2/WS2 MAE_es: 0.087 MAE_ds: 0.081
#
# --- MoS2/WS2 ---
# Starting calculations for P-MoS2/WS2
# XX'    DFT_d:6.822 ML_d:6.822 DFT_energy:-1.871 ML_energy:-1.823
# 2    DFT_d:6.510 ML_d:6.591 DFT_energy:-2.116 ML_energy:-2.030
# 3R(MX')    DFT_d:6.261 ML_d:6.205 DFT_energy:-2.565 ML_energy:-2.483
# 4    DFT_d:6.508 ML_d:6.315 DFT_energy:-2.387 ML_energy:-2.308
# 3R(XM')    DFT_d:6.250 ML_d:6.207 DFT_energy:-2.573 ML_energy:-2.476
# f(d)    DFT_d:6.509 ML_d:6.517 DFT_energy:-2.203 ML_energy:-2.094
# Starting calculations for AP-MoS2/WS2
# XX'    DFT_d:6.792 ML_d:6.802 DFT_energy:-1.904 ML_energy:-1.831
# 2    DFT_d:6.510 ML_d:6.596 DFT_energy:-2.141 ML_energy:-2.046
# 2H    DFT_d:6.270 ML_d:6.220 DFT_energy:-2.584 ML_energy:-2.507
# 4    DFT_d:6.510 ML_d:6.572 DFT_energy:-2.107 ML_energy:-2.012
# MM'    DFT_d:6.507 ML_d:6.230 DFT_energy:-2.381 ML_energy:-2.391
# f(d)    DFT_d:6.509 ML_d:6.509 DFT_energy:-2.206 ML_energy:-2.098
# MoS2/WS2 MAE_es: 0.080 MAE_ds: 0.072
#
# --- MoSe2/MoSe2 ---
# Starting calculations for P-MoSe2/MoSe2
# XX'    DFT_d:7.174 ML_d:7.218 DFT_energy:-1.818 ML_energy:-1.787
# 2    DFT_d:6.977 ML_d:6.977 DFT_energy:-2.055 ML_energy:-1.944
# 3R(MX')    DFT_d:6.501 ML_d:6.579 DFT_energy:-2.457 ML_energy:-2.317
# 4    DFT_d:6.706 ML_d:6.690 DFT_energy:-2.336 ML_energy:-2.191
# 3R(XM')    DFT_d:6.501 ML_d:6.579 DFT_energy:-2.457 ML_energy:-2.317
# f(d)    DFT_d:6.884 ML_d:6.898 DFT_energy:-2.131 ML_energy:-2.005
# Starting calculations for AP-MoSe2/MoSe2
# XX'    DFT_d:7.162 ML_d:7.220 DFT_energy:-1.853 ML_energy:-1.780
# 2    DFT_d:6.915 ML_d:6.964 DFT_energy:-2.084 ML_energy:-1.963
# 2H    DFT_d:6.501 ML_d:6.572 DFT_energy:-2.473 ML_energy:-2.412
# 4    DFT_d:6.984 ML_d:6.994 DFT_energy:-2.046 ML_energy:-1.920
# MM'    DFT_d:6.649 ML_d:6.606 DFT_energy:-2.328 ML_energy:-2.211
# f(d)    DFT_d:6.886 ML_d:6.898 DFT_energy:-2.130 ML_energy:-2.004
# MoSe2/MoSe2 MAE_es: 0.110 MAE_ds: 0.039
#
# --- WSe2/WSe2 ---
# Starting calculations for P-WSe2/WSe2
# XX'    DFT_d:7.206 ML_d:7.253 DFT_energy:-1.845 ML_energy:-1.833
# 2    DFT_d:7.001 ML_d:7.028 DFT_energy:-2.080 ML_energy:-1.977
# 3R(MX')    DFT_d:6.662 ML_d:6.625 DFT_energy:-2.483 ML_energy:-2.322
# 4    DFT_d:6.765 ML_d:6.745 DFT_energy:-2.349 ML_energy:-2.202
# 3R(XM')    DFT_d:6.662 ML_d:6.625 DFT_energy:-2.483 ML_energy:-2.322
# f(d)    DFT_d:6.929 ML_d:6.953 DFT_energy:-2.153 ML_energy:-2.033
# Starting calculations for AP-WSe2/WSe2
# XX'    DFT_d:7.185 ML_d:7.256 DFT_energy:-1.882 ML_energy:-1.826
# 2    DFT_d:6.988 ML_d:7.018 DFT_energy:-2.108 ML_energy:-1.993
# 2H    DFT_d:6.656 ML_d:6.617 DFT_energy:-2.526 ML_energy:-2.409
# 4    DFT_d:7.009 ML_d:7.047 DFT_energy:-2.069 ML_energy:-1.955
# MM'    DFT_d:6.750 ML_d:6.653 DFT_energy:-2.325 ML_energy:-2.231
# f(d)    DFT_d:6.931 ML_d:6.953 DFT_energy:-2.152 ML_energy:-2.032
# WSe2/WSe2 MAE_es: 0.110 MAE_ds: 0.041
#
# --- MoSe2/WSe2 ---
# Starting calculations for P-MoSe2/WSe2
# XX'    DFT_d:7.185 ML_d:7.234 DFT_energy:-1.839 ML_energy:-1.812
# 2    DFT_d:6.975 ML_d:7.000 DFT_energy:-2.077 ML_energy:-1.962
# 3R(MX')    DFT_d:6.510 ML_d:6.600 DFT_energy:-2.454 ML_energy:-2.330
# 4    DFT_d:6.738 ML_d:6.717 DFT_energy:-2.351 ML_energy:-2.201
# 3R(XM')    DFT_d:6.510 ML_d:6.605 DFT_energy:-2.466 ML_energy:-2.319
# f(d)    DFT_d:6.909 ML_d:6.924 DFT_energy:-2.150 ML_energy:-2.021
# Starting calculations for AP-MoSe2/WSe2
# XX'    DFT_d:7.170 ML_d:7.235 DFT_energy:-1.875 ML_energy:-1.804
# 2    DFT_d:6.954 ML_d:6.988 DFT_energy:-2.105 ML_energy:-1.981
# 2H    DFT_d:6.511 ML_d:6.595 DFT_energy:-2.489 ML_energy:-2.415
# 4    DFT_d:6.980 ML_d:7.018 DFT_energy:-2.067 ML_energy:-1.939
# MM'    DFT_d:6.708 ML_d:6.629 DFT_energy:-2.334 ML_energy:-2.224
# f(d)    DFT_d:6.911 ML_d:6.923 DFT_energy:-2.149 ML_energy:-2.021
# MoSe2/WSe2 MAE_es: 0.111 MAE_ds: 0.051

# %%
np.random.seed(10)
test_offsets = np.random.uniform(-1,1,(6,2))
#print(test_offsets)
P_stacks = {1:"T1",2:"T2",3:"T3",4:"T4",5:"T5",6:"T6"}
AP_stacks = P_stacks
stacknames = [P_stacks, AP_stacks]

initial_d = 6.65
foldername = 'espresso_relax_test/'

for tmdc1, tmdc2 in bilayers:
    print(f"--- {tmdc1}/{tmdc2} ---")
    
    dft_ds, dft_es, ml_ds, ml_es = np.zeros(12), np.zeros(12), np.zeros(12), np.zeros(12)
    for j, stacking in enumerate(['P', 'AP']):
        print(f'Starting calculations for {stacking}-{tmdc1}/{tmdc2}')
        offsets = test_offsets
        stacks = P_stacks 
        get_stacking_minima(tmdc1, tmdc2, stacking, test_offsets, stacks, initial_d, foldername,test=True)

    mae_es = np.mean(np.abs(dft_es - ml_es))
    mae_ds = np.mean(np.abs(dft_ds - ml_ds))
    print(f'{tmdc1}/{tmdc2} MAE_es: {mae_es:.3f} MAE_ds: {mae_ds:.3f}\n')
# Out:
# --- MoS2/MoS2 ---
# Starting calculations for P-MoS2/MoS2
# T1    DFT_d:6.650 ML_d:6.778 DFT_energy:-1.857 ML_energy:-1.836
# T2    DFT_d:6.350 ML_d:6.303 DFT_energy:-2.395 ML_energy:-2.285
# T3    DFT_d:6.229 ML_d:6.175 DFT_energy:-2.563 ML_energy:-2.487
# T4    DFT_d:6.650 ML_d:6.434 DFT_energy:-2.196 ML_energy:-2.143
# T5    DFT_d:6.651 ML_d:6.734 DFT_energy:-1.930 ML_energy:-1.877
# T6    DFT_d:6.650 ML_d:6.759 DFT_energy:-1.891 ML_energy:-1.854
# Starting calculations for AP-MoS2/MoS2
# T1    DFT_d:6.650 ML_d:6.763 DFT_energy:-1.899 ML_energy:-1.844
# T2    DFT_d:6.357 ML_d:6.313 DFT_energy:-2.361 ML_energy:-2.273
# T3    DFT_d:6.263 ML_d:6.192 DFT_energy:-2.568 ML_energy:-2.512
# T4    DFT_d:6.650 ML_d:6.440 DFT_energy:-2.204 ML_energy:-2.158
# T5    DFT_d:6.650 ML_d:6.724 DFT_energy:-1.962 ML_energy:-1.886
# T6    DFT_d:6.650 ML_d:6.746 DFT_energy:-1.931 ML_energy:-1.863
# MoS2/MoS2 MAE_es: 0.062 MAE_ds: 0.104
#
# --- WS2/WS2 ---
# Starting calculations for P-WS2/WS2
# T1    DFT_d:6.651 ML_d:6.810 DFT_energy:-1.864 ML_energy:-1.848
# T2    DFT_d:6.379 ML_d:6.345 DFT_energy:-2.403 ML_energy:-2.278
# T3    DFT_d:6.286 ML_d:6.225 DFT_energy:-2.561 ML_energy:-2.460
# T4    DFT_d:6.650 ML_d:6.474 DFT_energy:-2.224 ML_energy:-2.142
# T5    DFT_d:6.651 ML_d:6.765 DFT_energy:-1.942 ML_energy:-1.888
# T6    DFT_d:6.651 ML_d:6.791 DFT_energy:-1.901 ML_energy:-1.866
# Starting calculations for AP-WS2/WS2
# T1    DFT_d:6.650 ML_d:6.796 DFT_energy:-1.908 ML_energy:-1.851
# T2    DFT_d:6.649 ML_d:6.381 DFT_energy:-2.270 ML_energy:-2.239
# T3    DFT_d:6.290 ML_d:6.237 DFT_energy:-2.583 ML_energy:-2.491
# T4    DFT_d:6.650 ML_d:6.482 DFT_energy:-2.234 ML_energy:-2.158
# T5    DFT_d:6.650 ML_d:6.754 DFT_energy:-1.977 ML_energy:-1.894
# T6    DFT_d:6.650 ML_d:6.776 DFT_energy:-1.941 ML_energy:-1.871
# WS2/WS2 MAE_es: 0.068 MAE_ds: 0.129
#
# --- MoS2/WS2 ---
# Starting calculations for P-MoS2/WS2
# T1    DFT_d:6.660 ML_d:6.793 DFT_energy:-1.873 ML_energy:-1.849
# T2    DFT_d:6.358 ML_d:6.331 DFT_energy:-2.405 ML_energy:-2.289
# T3    DFT_d:6.264 ML_d:6.207 DFT_energy:-2.562 ML_energy:-2.480
# T4    DFT_d:6.658 ML_d:6.458 DFT_energy:-2.211 ML_energy:-2.149
# T5    DFT_d:6.660 ML_d:6.748 DFT_energy:-1.946 ML_energy:-1.890
# T6    DFT_d:6.660 ML_d:6.773 DFT_energy:-1.906 ML_energy:-1.867
# Starting calculations for AP-MoS2/WS2
# T1    DFT_d:6.660 ML_d:6.778 DFT_energy:-1.915 ML_energy:-1.856
# T2    DFT_d:6.380 ML_d:6.345 DFT_energy:-2.367 ML_energy:-2.273
# T3    DFT_d:6.274 ML_d:6.222 DFT_energy:-2.581 ML_energy:-2.504
# T4    DFT_d:6.658 ML_d:6.469 DFT_energy:-2.219 ML_energy:-2.163
# T5    DFT_d:6.660 ML_d:6.738 DFT_energy:-1.980 ML_energy:-1.900
# T6    DFT_d:6.660 ML_d:6.761 DFT_energy:-1.946 ML_energy:-1.876
# MoS2/WS2 MAE_es: 0.068 MAE_ds: 0.099
#
# --- MoSe2/MoSe2 ---
# Starting calculations for P-MoSe2/MoSe2
# T1    DFT_d:7.118 ML_d:7.176 DFT_energy:-1.865 ML_energy:-1.817
# T2    DFT_d:6.652 ML_d:6.728 DFT_energy:-2.283 ML_energy:-2.153
# T3    DFT_d:6.651 ML_d:6.583 DFT_energy:-2.470 ML_energy:-2.312
# T4    DFT_d:6.834 ML_d:6.719 DFT_energy:-2.295 ML_energy:-2.162
# T5    DFT_d:7.064 ML_d:7.090 DFT_energy:-1.951 ML_energy:-1.872
# T6    DFT_d:7.086 ML_d:7.139 DFT_energy:-1.902 ML_energy:-1.841
# Starting calculations for AP-MoSe2/MoSe2
# T1    DFT_d:7.110 ML_d:7.179 DFT_energy:-1.894 ML_energy:-1.810
# T2    DFT_d:6.651 ML_d:6.731 DFT_energy:-2.238 ML_energy:-2.147
# T3    DFT_d:6.651 ML_d:6.575 DFT_energy:-2.494 ML_energy:-2.406
# T4    DFT_d:6.845 ML_d:6.700 DFT_energy:-2.305 ML_energy:-2.220
# T5    DFT_d:7.058 ML_d:7.091 DFT_energy:-1.972 ML_energy:-1.870
# T6    DFT_d:7.069 ML_d:7.141 DFT_energy:-1.931 ML_energy:-1.837
# MoSe2/MoSe2 MAE_es: 0.096 MAE_ds: 0.073
#
# --- WSe2/WSe2 ---
# Starting calculations for P-WSe2/WSe2
# T1    DFT_d:7.154 ML_d:7.213 DFT_energy:-1.895 ML_energy:-1.862
# T2    DFT_d:6.652 ML_d:6.784 DFT_energy:-2.281 ML_energy:-2.168
# T3    DFT_d:6.651 ML_d:6.629 DFT_energy:-2.479 ML_energy:-2.318
# T4    DFT_d:6.875 ML_d:6.776 DFT_energy:-2.305 ML_energy:-2.173
# T5    DFT_d:7.096 ML_d:7.136 DFT_energy:-1.978 ML_energy:-1.911
# T6    DFT_d:7.128 ML_d:7.178 DFT_energy:-1.934 ML_energy:-1.884
# Starting calculations for AP-WSe2/WSe2
# T1    DFT_d:7.146 ML_d:7.218 DFT_energy:-1.923 ML_energy:-1.854
# T2    DFT_d:6.652 ML_d:6.785 DFT_energy:-2.233 ML_energy:-2.164
# T3    DFT_d:6.651 ML_d:6.621 DFT_energy:-2.521 ML_energy:-2.403
# T4    DFT_d:6.878 ML_d:6.761 DFT_energy:-2.321 ML_energy:-2.220
# T5    DFT_d:7.077 ML_d:7.141 DFT_energy:-2.001 ML_energy:-1.908
# T6    DFT_d:7.107 ML_d:7.183 DFT_energy:-1.960 ML_energy:-1.879
# WSe2/WSe2 MAE_es: 0.091 MAE_ds: 0.075
#
# --- MoSe2/WSe2 ---
# Starting calculations for P-MoSe2/WSe2
# T1    DFT_d:7.137 ML_d:7.192 DFT_energy:-1.889 ML_energy:-1.841
# T2    DFT_d:6.661 ML_d:6.755 DFT_energy:-2.295 ML_energy:-2.164
# T3    DFT_d:6.660 ML_d:6.604 DFT_energy:-2.478 ML_energy:-2.325
# T4    DFT_d:6.863 ML_d:6.741 DFT_energy:-2.306 ML_energy:-2.177
# T5    DFT_d:7.079 ML_d:7.112 DFT_energy:-1.972 ML_energy:-1.893
# T6    DFT_d:7.113 ML_d:7.157 DFT_energy:-1.927 ML_energy:-1.865
# Starting calculations for AP-MoSe2/WSe2
# T1    DFT_d:7.121 ML_d:7.196 DFT_energy:-1.917 ML_energy:-1.834
# T2    DFT_d:6.660 ML_d:6.758 DFT_energy:-2.248 ML_energy:-2.159
# T3    DFT_d:6.660 ML_d:6.599 DFT_energy:-2.515 ML_energy:-2.409
# T4    DFT_d:6.868 ML_d:6.731 DFT_energy:-2.319 ML_energy:-2.223
# T5    DFT_d:7.065 ML_d:7.115 DFT_energy:-1.994 ML_energy:-1.890
# T6    DFT_d:7.089 ML_d:7.159 DFT_energy:-1.954 ML_energy:-1.860
# MoSe2/WSe2 MAE_es: 0.098 MAE_ds: 0.075

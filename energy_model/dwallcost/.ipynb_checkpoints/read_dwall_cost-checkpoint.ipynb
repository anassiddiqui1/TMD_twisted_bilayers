# %%
import numpy as np
import matplotlib.pyplot as plt

def read_domain_wall_cost(filename):
    
    dwall_costs = []
    cost_change = []
    file  = open(filename)
    lines = file.readlines()
    for line in lines:
        if line[0]=='E':
            dwall_costs.append(float(line.split(':')[1]))
        if line[0]=='P':
            dwall_costs.append(float(line.split(':')[1]))
    return dwall_costs

# %%
m1 = 'Mo'
m2 = 'Mo'
x1 = 'S'

dwall_costs = read_domain_wall_cost(f'domain_wall_{m1}{m1}{x1}AP_recover_1.out')
dwall_costs
# Out:
# [0.08643360903136564,
#  0.08598209268786998,
#  0.08553471936264737,
#  0.08509337508394431,
#  0.08465443359805534,
#  0.08605397932633586,
#  0.08562094561667914,
#  0.08702623296254637,
#  0.08659698177208278,
#  0.08616886589004394,
#  0.08573950359667493,
#  0.08531153693467652,
#  0.08488129697687116,
#  0.08628622424554155,
#  0.08585182006983909,
#  0.08725064889222557,
#  0.08681070648876252,
#  0.08636865918411829]
